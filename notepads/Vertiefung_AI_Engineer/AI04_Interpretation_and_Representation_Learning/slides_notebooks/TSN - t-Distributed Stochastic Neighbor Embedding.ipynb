# %% [markdown]
# # t-Distributed Stochastic Neighbor Embedding (t-SNE)

# %% [markdown]
# ## Imports

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torchvision.datasets as datasets

# %% [markdown]
# ## Datengrundlage

# %%
n = 5000
mnist = datasets.MNIST(root='./data', train=True, download=True, transform=None)
x = mnist.data.numpy().reshape(60000,-1)[:n]
y = mnist.targets.numpy()[:n]

# %% [markdown]
# ## t-SNE trainieren

# %%
tsne = TSNE(n_iter=1000)
embedding = tsne.fit_transform(x)
# Out:
# /Users/lauraboenchen/Workspace/Digethic/full-stack-machine-learning/.venv/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
plt.figure(figsize=(14,6))
for i in range(10):
    plt.scatter(embedding[np.where(y==i),:1],embedding[np.where(y==i),1:],label=str(i),alpha=0.4)
plt.legend()
plt.title("MNIST t-SNE Embedding")
plt.show()

# %% [markdown]
# ## Vergleich mit PCA

# %%
pca = PCA(n_components=2)
pca_embedding = pca.fit_transform(x)

# %%
plt.figure(figsize=(14,6))
for i in range(10):
    plt.scatter(pca_embedding[np.where(y==i),:1],pca_embedding[np.where(y==i),1:],label=str(i),alpha=0.4)
plt.legend()
plt.title("MNIST PCA Embedding")
plt.show()
