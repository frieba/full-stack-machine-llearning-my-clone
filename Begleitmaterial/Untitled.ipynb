# %%
Aufgabe 1: Einführung in Python

# %%
import pandas as pd
import numpy as np
import os
from sklearn.tree import train_test_split

print("hello world")
#file_path = os.path.join("..", "..", "..", "data", "census.csv")
#census = pd.read_csv("data/census.csv", sep=",", header=0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import os
#
# ModuleNotFoundError: No module named 'pandas'
